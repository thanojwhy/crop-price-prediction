# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("all_commodities.csv")
df.head()
# Out:
#    Unnamed: 0      State   District     Market Commodity Variety Grade  \
# 0           0  Karnataka  Bangalore  Bangalore      Rice  Coarse   FAQ
# 1           1  Karnataka  Bangalore  Bangalore      Rice  Coarse   FAQ
# 2           2  Karnataka  Bangalore  Bangalore      Rice  Coarse   FAQ
# 3           3  Karnataka  Bangalore  Bangalore      Rice  Coarse   FAQ
# 4           4  Karnataka  Bangalore  Bangalore      Rice  Coarse   FAQ
#
#   Arrival_Date  Min_Price  Max_Price  Modal_Price  Commodity_Code  Year  \
# 0   04/08/2001      900.0     1000.0          950               3  2001
# 1   04/08/2001      900.0     1000.0          950               3  2001
# 2   04/08/2001      900.0     1000.0          950               3  2001
# 3   20/12/2001      900.0      500.0          400               3  2001
# 4   20/12/2001      900.0      500.0          400               3  2001
#
#         Season       Area  Production  Annual_Rainfall    Fertilizer  \
# ...

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df.dtypes
# Out:
# State               object
# District            object
# Market              object
# Commodity           object
# Variety             object
# Grade               object
# Arrival_Date        object
# Min_Price          float64
# Max_Price          float64
# Modal_Price          int64
# Commodity_Code       int64
# Year                 int64
# Season              object
# Area               float64
# Production         float64
# Annual_Rainfall    float64
# Fertilizer         float64
# Pesticide          float64
# Yield              float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# State              0
# District           0
# Market             0
# Commodity          0
# Variety            0
# Grade              0
# Arrival_Date       0
# Min_Price          2
# Max_Price          2
# Modal_Price        0
# Commodity_Code     0
# Year               0
# Season             0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# State              0
# District           0
# Market             0
# Commodity          0
# Variety            0
# Grade              0
# Arrival_Date       0
# Min_Price          0
# Max_Price          0
# Modal_Price        0
# Commodity_Code     0
# Year               0
# Season             0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df.shape
# Out:
# (166894, 19)

# %%
df['Year'].unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
df.describe()
# Out:
#            Min_Price      Max_Price    Modal_Price  Commodity_Code  \
# count  166894.000000  166894.000000  166894.000000   166894.000000
# mean     1340.523338    1642.025519    1435.045981       12.820683
# std       928.894790    1066.184885     938.826180       10.578282
# min        41.000000     160.000000     115.000000        1.000000
# 25%       778.000000    1000.000000     850.000000        3.000000
# 50%      1085.000000    1350.000000    1175.000000        3.000000
# 75%      1600.000000    2000.000000    1700.000000       23.000000
# max     13000.000000   45000.000000   14000.000000       24.000000
#
#                 Year          Area    Production  Annual_Rainfall  \
# count  166894.000000  1.668940e+05  1.668940e+05    166894.000000
# mean     2010.813247  1.151751e+06  3.544380e+06      1089.261661
# std         5.014873  2.293100e+06  7.205330e+06       219.010604
# min      2001.000000  6.100000e+01  6.300000e+02       585.800000
# ...

# %%
df.to_csv('all_commodities.csv',index=False)
