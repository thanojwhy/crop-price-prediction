# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("commodities.csv")
df.head()
# Out:
#      State District    Market              Commodity      Variety Grade  \
# 0  Gujarat   Amreli  Damnagar  Bhindi(Ladies Finger)       Bhindi   FAQ
# 1  Gujarat   Amreli  Damnagar                Brinjal        Other   FAQ
# 2  Gujarat   Amreli  Damnagar                Cabbage      Cabbage   FAQ
# 3  Gujarat   Amreli  Damnagar            Cauliflower  Cauliflower   FAQ
# 4  Gujarat   Amreli  Damnagar      Coriander(Leaves)    Coriander   FAQ
#
#   Arrival_Date  Min Price  Max Price  Modal Price
# 0   27-07-2023     4100.0     4500.0       4350.0
# 1   27-07-2023     2200.0     3000.0       2450.0
# 2   27-07-2023     2350.0     3000.0       2700.0
# 3   27-07-2023     7000.0     7500.0       7250.0
# 4   27-07-2023     8400.0     9000.0       8850.0

# %%
df.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Grade',
#        'Arrival_Date', 'Min Price', 'Max Price', 'Modal Price'],
#       dtype='object')

# %%
df.shape
# Out:
# (23093, 10)

# %%
df.isnull().sum()
# Out:
# State           0
# District        0
# Market          0
# Commodity       0
# Variety         0
# Grade           0
# Arrival_Date    0
# Min Price       0
# Max Price       0
# Modal Price     0
# dtype: int64

# %%
df['Commodity'].value_counts()
# Out:
# Commodity
# Potato                      1205
# Onion                       1134
# Brinjal                     1033
# Green Chilli                 931
# Bhindi(Ladies Finger)        860
#                             ...
# Alasande Gram                  1
# Almond(Badam)                  1
# Cinamon(Dalchini)              1
# Broomstick(Flower Broom)       1
# She Buffalo                    1
# Name: count, Length: 234, dtype: int64

# %%
df1=pd.read_csv("ICRISAT-ALL Years.csv")
df1
# Out:
#        Dist Code  Year  State Code    State Name  Dist Name  \
# 0              1  1966          14  Chhattisgarh       Durg
# 1              1  1967          14  Chhattisgarh       Durg
# 2              1  1968          14  Chhattisgarh       Durg
# 3              1  1969          14  Chhattisgarh       Durg
# 4              1  1970          14  Chhattisgarh       Durg
# ...          ...   ...         ...           ...        ...
# 15125        917  1985          15     Jharkhand  Singhbhum
# 15126        917  1986          15     Jharkhand  Singhbhum
# 15127        917  1987          15     Jharkhand  Singhbhum
# 15128        917  1988          15     Jharkhand  Singhbhum
# 15129        917  1989          15     Jharkhand  Singhbhum
#
#        RICE HARVEST PRICE (Rs per Quintal)  \
# 0                                     -1.0
# 1                                    110.0
# 2                                     98.8
# 3                                     94.0
# ...

# %%
temp=df1 
temp.drop(['Dist Code','Year','State Code','State Name','Dist Name'],axis=1,inplace=True)
temp.astype('float')
# Out:
#        RICE HARVEST PRICE (Rs per Quintal)  \
# 0                                     -1.0
# 1                                    110.0
# 2                                     98.8
# 3                                     94.0
# 4                                     95.4
# ...                                    ...
# 15125                                 -1.0
# 15126                                 -1.0
# 15127                                 -1.0
# 15128                                 -1.0
# 15129                                 -1.0
#
#        PADDY HARVEST PRICE (Rs per Quintal)  \
# 0                                     -1.00
# 1                                     -1.00
# 2                                     -1.00
# 3                                     -1.00
# 4                                     -1.00
# ...                                     ...
# 15125                                181.09
# 15126                                162.80
# ...

# %%
temp=temp.replace(-1.0,np.nan)

# %%
temp.isnull().sum()
# Out:
# RICE HARVEST PRICE (Rs per Quintal)                11762
# PADDY HARVEST PRICE (Rs per Quintal)                6338
# WHEAT HARVEST PRICE (Rs per Quintal)                5041
# SORGHUM HARVEST PRICE (Rs per Quintal)              7242
# PEARL MILLET HARVEST PRICE (Rs per Quintal)         8352
# MAIZE HARVEST PRICE (Rs per Quintal)                6445
# FINGER MILLET HARVEST PRICE (Rs per Quintal)       11562
# BARLEY HARVEST PRICE (Rs per Quintal)              10031
# CHICKPEA HARVEST PRICE (Rs per Quintal)             5425
# PIGEONPEA HARVEST PRICE (Rs per Quintal)            8035
# GROUNDNUT HARVEST PRICE (Rs per Quintal)            7133
# SEASMUM HARVEST PRICE (Rs per Quintal)              6677
# RAPE AND MUSTARD HARVEST PRICE (Rs per Quintal)     8654
# CASTOR HARVEST PRICE (Rs per Quintal)              12265
# LINSEED HARVEST PRICE (Rs per Quintal)             11114
# SUGARCANE GUR HARVEST PRICE (Rs per Quintal)        7929
# ...
